# %%
# Import the required libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from pandas import DataFrame, Series
import re
import dateutil.parser
from word2number import w2n

# %%
baseurl = 'https://www.interest.co.nz/property/residential-auction-results?&page='

# %%
def create_urls(baseurl):
    num_pages = (31039/25) + 1
    urls = []
    for i in range(num_pages):
        i = i + 1
        url = baseurl+str(i)
        urls.append(url)
    return urls

# %%
allurls = create_urls(baseurl)

# %%
#testurls = ["https://www.interest.co.nz/property/residential-auction-results?region=Auckland&district=Waitakere%20City&area=Hobsonville&agency=-&status=Sold&page=1"]
#testurls

# %%
def scrapdata(allurls):
    out = []
    for url in allurls:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "lxml")
        for listing in soup.find_all('div', id="padb-property-card"):
            property_id = listing.find('div', id="padb-property-id").get_text().strip()
            property_region = listing.find('div', id="padb-property-region").get_text().strip()
            property_address = listing.find('div', id="padb-property-address").get_text().strip()
            property_details = listing.find('div', id="padb-property-details").get_text().strip()
            property_agency = listing.find('div', id="padb-property-agency").get_text().strip()
            property_agents = listing.find('div', id="padb-property-agents").get_text().strip()
            property_auctiondetails = listing.find('div', id="padb-property-auction-details").get_text().strip()
            property_value = listing.find('div', id="padb-property-value").get_text().strip()
            df_dict = dict({'property_id' : property_id,'property_region' : property_region,
                    'property_address' : property_address, 'property_details' : property_details,
                     'property_agency' : property_agency, 'property_agents' : property_agents,
                    'property_auctiondetails' : property_auctiondetails,'property_value' : property_value})
            out.append(df_dict)
    return out

# %%
out = scrapdata(allurls)

# %%
scrapped_data = pd.DataFrame.from_dict(out, orient='columns')

# %%
scrapped_data.to_pickle('scrapped_data.pkl')

# %%
scrapped_data = pd.read_pickle('scrapped_data.pkl')

# %%
#Cleaning agent names
def get_agent_names(row):
    s = row['property_agents']
    return s.replace("Agent(s): ","").replace("(contact)","")


scrapped_data['property_agents_cleaned'] = scrapped_data.apply(get_agent_names, axis=1)

# %%
#Cleaning property id
def get_property_id(row):
    s = row['property_id']
    return re.match(r'Listing ID:(.*)', s).group(1)

scrapped_data['property_id_cleaned'] = scrapped_data.apply(get_property_id, axis=1)

# %%
#Getting auction date
def get_auction_date_old(row):
    s = row['property_auctiondetails'].strip()
    matched = re.match(r'Auction details:\s(.*)', s)
    if matched:
        if '(On site)' in matched.group(1):
            return matched.group(1).replace("(On site)","")
        else:
            return matched.group(1)
    else:
        return ''

def get_auction_date(row):
    s = row['property_auctiondetails'].strip()
    return re.match(r'Auction details:\s*(.*)', s).group(1)

def get_auction_date_new(row):
    s = row['property_auctiondetails'].strip()
    mon = r'(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|(?:Nov|Dec)(?:ember)?)'
    day1 = r'\d{1,2}(?:st|nd|rd|th)?'
    year1 = r'\b\d{2}(?:\d{2})?\b'
    dummy = r'.*'
    rx = "((?:{smon}\s+{sday1}|{sday1}\s+{smon}))(?:{sdummy}({syear1}))?".format(smon=mon, sday1=day1, sdummy=dummy, syear1=year1)
    m = re.search(rx, s)
    if m:
        return("{} {}".format(m.group(1), m.group(2)))
    else:
        return("NO MATCH")

scrapped_data['auction_date'] = scrapped_data.apply(get_auction_date_new, axis=1)

# %%
def sold_or_not(row):
    s = row['property_value'].strip()
    if 'Passed in' in s:
        out = 'Not_Sold'
    elif 'Withdrawn' in s:
        out = 'Not_Sold'
    elif s == '':
        out = 'Not_Sold'
    else:
        out = 'Sold'
    return out

def sold_or_notv1(row):
    s = row['property_value'].strip()
    if s:
        if s[0].isdigit():
            out = 'Sold'
        elif s[0] == 'S':
            out = 'Sold'
        else:
            out = 'Not_Sold'
    else:
        out = 'Not_Sold'
    return out
 
#scrapped_test = scrapped_data.tail()
#scrapped_test['sold_or_not'] = scrapped_test.apply(sold_or_notv1, axis=1)

scrapped_data['sold_or_not'] = scrapped_data.apply(sold_or_notv1, axis=1)

# %%
def sold_or_not_test(s):
    s = s.strip()
    if s:
        if s[0].isdigit():
            out = 'Sold'
        elif s[0] is 'S':
            out = 'Sold'
        else:
            out = 'Not_Sold'
    else:
        out = 'Not_Sold'
    return out

# %%
sold_or_not_test('Sold for:$500,000')
# Out:
# 'Sold'

# %%
def parse_date(row):
    if row.auction_date == 'February 20 None':
        row.auction_date = 'February 20 2017'
    elif row.auction_date == '13 October 34':
        row.auction_date = '13 October 2016'
    elif row.auction_date == '29 September 34':
        row.auction_date = '29 September 2016'
    elif row.auction_date == '2 February 34':
        row.auction_date = '2 February 2016'
    elif row.auction_date == '7th September 34':
        row.auction_date = '7 September 2016'
    elif row.auction_date == '28 September 34':
        row.auction_date = '28 September 2016'
    else:
        row.auction_date = row.auction_date
    if row.auction_date != 'NO MATCH':
        return dateutil.parser.parse(row.auction_date)
    else:
        return ''

# %%
scrapped_data['auction_date'] = scrapped_data.apply(parse_date, axis=1)

# %%
def get_num_bed(row):
    s = row['property_details'].strip()
    rgx = r'(\w+) *(?:double +)?bed(room)?s?|bed(?:room)?s?:? *(\d+)'
    m = re.search(rgx, s.lower())
    if m :
        return filter(lambda x: x.isdigit(), m.group())
    
def get_num_bath(row):
    s = row['property_details'].strip()
    rgx = r'(\w+) *(?:double +)?bath(room)?s?|bath(?:room)?s?:? *(\d+)'
    m = re.search(rgx, s.lower())
    if m :
        return filter(lambda x: x.isdigit(), m.group())

# %%
def getbedRoomInfo(row):
    s = row['property_details'].strip()
    numRooms = re.search(r'(\w+\+?) *(?:double +)?bed(?:room)?s?|bed(?:room)?s?:? *(\d+\+?)', s, re.IGNORECASE)
    if (numRooms):
        if (numRooms.group(1) is not None):
            return numRooms.group(1).lower()
        elif (numRooms.group(2) is not None):
            return numRooms.group(2).lower()

# %%
def getbathRoomInfo(row):
    s = row['property_details'].strip()
    numRooms = re.search(r'(\w+\+?) *(?:double +)?bath(?:room)?s?|bath(?:room)?s?:? *(\d+\+?)', s, re.IGNORECASE)
    if (numRooms):
        if (numRooms.group(1) is not None):
            return numRooms.group(1).lower()
        elif (numRooms.group(2) is not None):
            return numRooms.group(2).lower()

# %%
#test = scrapped_data.head(10)
#test['num_bedrooms'] = test.apply(getbedRoomInfo, axis=1)

# %%
di = {"zero": 0 , "one": 2, "two" : 2, "three" : 3, "four" : 4,
      "five" : 5, "six" : 6, "seven" : 7, "eight" : 8, "nine" : 9, "ten" : 10, "eleven" : 11}

# %%
scrapped_data['num_bedrooms'] = scrapped_data.apply(getbedRoomInfo, axis=1)

# %%
scrapped_data['num_bedrooms'] = scrapped_data['num_bedrooms'].str.replace('+','')
scrapped_data['num_bedrooms'] = scrapped_data['num_bedrooms'].str.strip()
scrapped_data['num_bedrooms'] = scrapped_data['num_bedrooms'].map(di).fillna(scrapped_data['num_bedrooms'])

# %%
#scrapped_data['num_bedrooms'] = scrapped_data.apply(getbedRoomInfo, axis=1)
#scrapped_data['num_bedrooms'] = scrapped_data.apply(bed_convert_to_num, axis=1)

# %%
scrapped_data['num_bathrooms'] = scrapped_data.apply(getbathRoomInfo, axis=1)
scrapped_data['num_bathrooms'] = scrapped_data['num_bathrooms'].str.replace('+','')
scrapped_data['num_bathrooms'] = scrapped_data['num_bathrooms'].str.strip()
scrapped_data['num_bathrooms'] = scrapped_data['num_bathrooms'].map(di).fillna(scrapped_data['num_bathrooms'])

# %%
scrapped_data.to_csv('scrapped_data.csv', index = False,encoding='utf-8')

# %%
scrapped_data[scrapped_data.property_id_cleaned.isin(['ebt3177','ech1146','578663'])]
# Out:
#                              property_address     property_agency  \
# 208            81 Lynley Park Drive, Omokoroa                Eves
# 211               23 Emmerdale Place, Ohauiti                Eves
# 27249  8 Reipae Street, Stonefields, Auckland  Barfoot & Thompson
#
#                                          property_agents  \
# 208    Agent(s): Ron Beccard (contact), Debi Bennett ...
# 211                      Agent(s): Chris Royal (contact)
# 27249                           Agent(s): Paul Neshausen
#
#                                  property_auctiondetails  \
# 208         Auction details: Thursday, 28th February '19
# 211         Auction details: Thursday, 28th February '19
# 27249  Auction details: 14 September 2016, Shortland ...
#
#                                 property_details         property_id  \
# 208    3+ bedroom(s), 2 bathroom(s), 3 garage(s)  Listing ID:ebt3177
# 211    3+ bedroom(s), 2 bathroom(s), 2 garage(s)  Listing ID:ech1146
# 27249          Four bedroom home , double garage   Listing ID:578663
#
#                             property_region property_value  \
# 208    Bay of Plenty, Western Bay Of Plenty      Passed In
# 211    Bay of Plenty, Western Bay Of Plenty      Passed In
# 27249               Auckland, Auckland City      Passed in
#
#            property_agents_cleaned property_id_cleaned auction_date  \
# 208    Ron Beccard , Debi Bennett              ebt3177   2019-02-28
# 211                   Chris Royal              ech1146   2019-02-28
# 27249               Paul Neshausen              578663   2016-09-14
#
#       sold_or_not num_bedrooms
# 208      Not_Sold            3
# 211      Not_Sold            3
# 27249    Not_Sold            4

# %%
def bed_convert_to_num(row):
    mylist = ["zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen"]
    s = row.num_bedrooms
    if (s is not None):
        print s
        print 'Number'
        s = str(s.replace('+',''))
        if not s.isdigit():
            if s in mylist:
                out = w2n.word_to_num(s)
            else:
                out = None
    else:
        out = None
        print 'text'
    return out

def bath_convert_to_num(row):
    s = row.num_bathrooms
    if (s is not None):
        s = str(s.replace('+',''))
        if not s.isdigit():
            try:
                return w2n.word_to_num(s)
            except ValueError as e:
                return None
    else:
        return s

# %%
#scrapped_data[scrapped_data.auction_date.isnull()]

# %%
#scrapped_data.tail()

# %%
scrapped_data[scrapped_data.num_bedrooms.isnull()].head()
# Out:
#                                      property_address     property_agency  \
# 0                                 38 Main Road, Tirau             Bayleys
# 1   Ground floor 118 Rostrevor Street, Hamilton Ce...             Bayleys
# 2                        195 Te Kawana Road, Te Aroha             Bayleys
# 26                    A/29 Birdwood Crescent, Parnell             Bayleys
# 69                        92 Pleasant Road, Titirangi  Barfoot & Thompson
#
#                                       property_agents  \
# 0   Agent(s): Mike Swanson (contact), Alex Ten Hov...
# 1   Agent(s): David Cashmore (contact), Sarah Liu ...
# 2   Agent(s): Josh Smith (contact), David Cashmore...
# 26  Agent(s): Kate Kirby (contact), Stephen Scott ...
# 69               Agent(s): Alan Hyslop and Robyn Rule
#
#                       property_auctiondetails  \
# 0    Auction details: Thursday, 7th March '19
# 1    Auction details: Thursday, 7th March '19
# 2    Auction details: Thursday, 7th March '19
# 26  Auction details: Wednesday, 6th March '19
# 69   Auction details: Saturday, 2nd March '19
#
#                                      property_details         property_id  \
# 0                                                      Listing ID:2310304
# 1                                                      Listing ID:2310273
# 2                                              365m²,  Listing ID:2310206
# 26  Block of seven 1960s-era units, each on its ow...  Listing ID:1687521
# 69                                                      Listing ID:770178
#
#              property_region  \
# 0     Waikato, South Waikato
# 1     Waikato, Hamilton City
# 2    Waikato, Matamata-Piako
# 26   Auckland, Auckland City
# 69  Auckland, Waitakere City
#
#                                        property_value  \
# 0   Sold for:$518,000Rating Valuation:(July '18)$3...
# 1                                           Passed In
# 2                                           Withdrawn
# 26                                Sold for:$4,025,000
# 69  Sold for:$850,000Rating Valuation:(July '17)$9...
#
#                    property_agents_cleaned property_id_cleaned auction_date  \
# 0            Mike Swanson , Alex Ten Hove              2310304   2019-03-07
# 1   David Cashmore , Sarah Liu (Hamilton)              2310273   2019-03-07
# 2             Josh Smith , David Cashmore              2310206   2019-03-07
# 26             Kate Kirby , Stephen Scott              1687521   2019-03-06
# 69              Alan Hyslop and Robyn Rule              770178   2019-03-02
#
#    sold_or_not num_bedrooms num_bathrooms
# 0         Sold         None          None
# 1     Not_Sold         None          None
# 2     Not_Sold         None          None
# 26        Sold         None          None
# 69        Sold         None          None

# %%
test = scrapped_data[scrapped_data.property_id_cleaned.isin(['579087','578396','578663'])]
#scrapped_data[scrapped_data.index.isin([579087])]

# %%
test.head()
# Out:
#                                  property_address     property_agency  \
# 27229  5A/22 Emily Place, Auckland City, Auckland  Barfoot & Thompson
# 27232       1/7 Sprott Road, Kohimarama, Auckland  Barfoot & Thompson
# 27249      8 Reipae Street, Stonefields, Auckland  Barfoot & Thompson
#
#                           property_agents  \
# 27229  Agent(s): Aken Yuan and Tony Jiang
# 27232              Agent(s): Matt O'Brien
# 27249            Agent(s): Paul Neshausen
#
#                                  property_auctiondetails  \
# 27229  Auction details: 14 September 2016, Shortland ...
# 27232  Auction details: 14 September 2016, Shortland ...
# 27249  Auction details: 14 September 2016, Shortland ...
#
#                         property_details        property_id  \
# 27229   Two bedroom apartment with views  Listing ID:579087
# 27232                  Four bedroom home  Listing ID:578396
# 27249  Four bedroom home , double garage  Listing ID:578663
#
#                property_region property_value   property_agents_cleaned  \
# 27229  Auckland, Auckland City      Passed in  Aken Yuan and Tony Jiang
# 27232  Auckland, Auckland City      Passed in              Matt O'Brien
# 27249  Auckland, Auckland City      Passed in            Paul Neshausen
#
#       property_id_cleaned auction_date sold_or_not num_bedrooms num_bathrooms
# 27229              579087   2016-09-14    Not_Sold          Two          None
# 27232              578396   2016-09-14    Not_Sold         Four          None
# 27249              578663   2016-09-14    Not_Sold         Four          None

# %%
import re

def getRoomInfo(s):
    s = s.strip()
    numRooms = re.search(r'(\w+\+?) *(?:double +)?bed(?:room)?s?|bed(?:room)?s?:? *(\d+\+?)', s, re.IGNORECASE)
    if (numRooms):
        if (numRooms.group(1) is not None):
            return numRooms.group(1)
        elif (numRooms.group(2) is not None):
            return numRooms.group(2)


#arr = ['Two bedroom apartment with views','4 bedrooms 2 bathrooms 3 carparks','3 bedroom house','Bedrooms 2, ','beds 5,','Bedrooms 1, ','2 bedrooms, 1 bathroom, ','Four bedrooms home, double garage','Four bedrooms home','Three double bedrooms home, garage','Three bedrooms home,','2 bedroom home unit with single carport.','Garage car spaces: 2, Bathrooms: 4, Bedrooms: 7,\\\\', 'Three bedroom bungalow with conservatory and", "One bedroom unit","4+ bedroom(s), 2 bathroom(s), 2 garage(s)']
arr = list(test.property_details)
for s in arr:
    print(s, ' --> ', getRoomInfo(s))
# Out:
# (u'Two bedroom apartment with views', ' --> ', u'Two')
# (u'Four bedroom home', ' --> ', u'Four')
# (u'Four bedroom home , double garage', ' --> ', u'Four')

# %%
#scrapped_data = scrapped_data.join(scrapped_data['auction_date'].str.split(' ', expand=True).add_prefix('actiondate').fillna(np.nan))

# %%
print(len(scrapped_data[scrapped_data.actiondate3.notnull()]))
# Out:
# 34

# %%
#date1 = "February 20 2017"
#dateutil.parser.parse(date1)
# Out:
# datetime.datetime(2017, 2, 20, 0, 0)

# %%
scrapped_data[scrapped_data.actiondate3.notnull()]
# Out:
#                                         property_address     property_agency  \
# 25357                15 Mural Place, Greenhithe,Auckland  Barfoot & Thompson
# 25358                  51 Park Road, Glenfield, Auckland  Barfoot & Thompson
# 25359  575 Laurie Southwick Parade, Gulf Harbour, Auc...  Barfoot & Thompson
# 25360                 177 Metcalfe Road, Ranui, Auckland  Barfoot & Thompson
# 25361               6 Phillips Road, Warkworth, Auckland  Barfoot & Thompson
# 25362               9 Steamer Road, Silverdale, Auckland  Barfoot & Thompson
# 25363              10 Woodall Place, Glenfield, Auckland  Barfoot & Thompson
# 25364                16A Bay Street, Red Beach, Auckland  Barfoot & Thompson
# 25365                30 Hornbill Drive, Albany, Auckland  Barfoot & Thompson
# 25366        5/242 Great North Road, Henderson, Auckland  Barfoot & Thompson
# 25372  Single level home, four bedrooms , set on a 89...  Listing ID:579547
# 25373                                 Four bedrooms home  Listing ID:579659
# 25374                                Three bedrooms home  Listing ID:579601
# 25375  Four double bedrooms home, plus a self contain...  Listing ID:580328
# 25376  Four bedrooms home, double internal access garage  Listing ID:579816
# 25377  1980's home, three double bedrooms, internal g...  Listing ID:579785
# 25378                     Home with views, double garage  Listing ID:579380
# 25379                          109 Eban Avenue, Auckland  Listing ID:579602
# 25380  Single level home, brick and tile, three doubl...  Listing ID:579768
# 25381       Three bedrooms home, garage, set on a 809sqm  Listing ID:579860
# 25382                 Three double bedrooms home, garage  Listing ID:579616
# 25383          Four bedrooms home, with open plan living  Listing ID:579670
# 25384                 Four bedrooms home , double garage  Listing ID:579242
# 25385                                Brick and tile home  Listing ID:579696
# 25386                 Three bedrooms home, single garage  Listing ID:579814
# 25387                                 Four bedrooms home  Listing ID:579826
# 25388  Four bedrooms home, heated swimming pool, doub...  Listing ID:580297
# 25389  The home with backyard, sleep-out, lock up garage  Listing ID:579906
# 25704                                  Two bedrooms home  Listing ID:579639
#
#                   property_region       property_value  \
# 25357  Auckland, North Shore City  Sold for:$1,210,000
# 25358  Auckland, North Shore City            Passed in
# 25359            Auckland, Rodney            Passed in
# 25360    Auckland, Waitakere City            Passed in
# 25361            Auckland, Rodney    Sold for:$880,000
# 25362            Auckland, Rodney            Passed in
# 25363  Auckland, North Shore City            Passed in
# 25364            Auckland, Rodney    Sold for:$697,000
# 25365  Auckland, North Shore City  Sold for:$1,500,000
# 25366    Auckland, Waitakere City            Passed in
# 25367          Northland, Kaipara    Sold for:$776,000
# 25368            Auckland, Rodney    Sold for:$740,000
# 25369  Auckland, North Shore City            Passed in
# 25370  Auckland, North Shore City            Passed in
# 25371            Auckland, Rodney            Passed in
# 25372  Auckland, North Shore City            Passed in
# 25373            Auckland, Rodney            Passed in
# 25374            Auckland, Rodney            Passed in
# 25375  Auckland, North Shore City  Sold for:$1,215,000
# 25376  Auckland, North Shore City            Passed in
# 25377  Auckland, North Shore City            Passed in
# 25378            Auckland, Rodney            Passed in
# 25379  Auckland, North Shore City    Sold for:$915,000
# 25380            Auckland, Rodney            Passed in
# 25381  Auckland, North Shore City            Passed in
# 25382  Auckland, North Shore City            Passed in
# 25383  Auckland, North Shore City            Passed in
# 25384  Auckland, North Shore City            Passed in
# 25385  Auckland, North Shore City            Passed in
# 25386  Auckland, North Shore City    Sold for:$820,000
# 25387  Auckland, North Shore City  Sold for:$1,080,000
# 25388  Auckland, North Shore City            Passed in
# 25389  Auckland, North Shore City            Passed in
# 25704  Auckland, North Shore City    Sold for:$445,000
#
#                 property_agents_cleaned property_id_cleaned     auction_date  \
# 25357       Analia Gentile and Titus Lu              580625  6  October 2016
# 25358            Jacky Yu and Jane Wang              578732  6  October 2016
# 25359        Maxwell Zhu and Wendy Wang              579806  6  October 2016
# 25360                        Cleo Zhang              579928  6  October 2016
# 25361                         David Dai              579297  6  October 2016
# 25362                      Anna Langdon              575146  6  October 2016
# 25363                          Brian Li              579832  6  October 2016
#
#              property_value             property_agents_cleaned  \
# 21700             Passed in                           Jessie Lu
# 21701   Sold for:$1,590,000             Raylene Yang, Sam Zhang
# 21702     Sold for:$764,000            Pamela Cox, Nadia Ansell
# 21703     Sold for:$532,000                      Justin Coleman
# 21704             Passed in                           Alex Shin
# 21705             Passed in        Michael Benns, Denzil Pi\nto
# 21706   Sold for:$1,060,000             Joseph Lee, Kasey Wayne
# 21707             Passed in                           Tim Mahon
# 21708   Sold for:$1,150,000    Charlotte Conroy, Kathlyn Xavier
# 21709  Sold for:$Sold prior               Cici Yang, Ritz, Zhao
# 21710             Passed In                    Scott MacDonald
# 21711     Sold for:$430,000   Dylan McKenzie , Nicholas Warnes
# 21712     Sold for:$180,000                        Shaun Davey
# 21713             Passed In                     Jamin Marshall
# 21714             Passed In                    Louise McLeavey
# 21715     Sold for:$655,000                         Tim Sprott
# 21716             Passed In      Estelle Yang , Phil Rotherham
# 21717             Passed In                     Phil Rotherham
# 21718             Passed In      Alister Eddington , Lisa Wong
# 21719     Sold for:$395,000       Katrina Pitman , Kyle Pitman
# 21720                                            Ayliss Ripley
# 21721     Sold for:$755,000              Richard Tait (Taitie)
# 21722     Sold for:$520,000                        Gael Kofoed
# 21723             Passed In             Ashley Sutherland Todd
# 21724     Sold for:$255,000                        Heath Kelly
# 21725             Passed In                         Clare Beer
# 21726             Passed In                     Cameron Bailey
# 21727     Sold for:$340,000       Tess Maley , Peter Griffioen
# 21728     Sold for:$970,000                     Sandra O'Brien
# 21729     Sold for:$190,000  Caleb Griffioen , Peter Griffioen
# ...                     ...                                 ...
# 21770     Sold for:$825,000     Rodger van Kempen , Liz Hurley
# 21771             Passed In                     Rachel Simpson
# 21772     Sold for:$575,000      Kiri Hemmingson , Ash Kharche
# 21773   Sold for:$1,200,000                       Fiona Cooper
# 21774             Passed In                     Jason Yianakis
# 21775   Sold for:$1,000,202          Rubal Singh , Harry Saini
# 21776             Passed in                    Wayne Johansson
# 21777     Sold for:$975,000      Phil Sulusulu , Ann Lereculey
# 21778             Passed in                    Nick Vitasovich
# 21779             Passed In       Maureen Spyve , Scott Strong
# 21780             Passed In                     Karl Vermeulen
# 21781             Passed in                Jo-Ann Day-Townsend
# 21782             Passed in                     Avalon Sanders
# 21783             Passed In                         Fiona Wang
# 21784             Passed in                Wayne Guo, Coco Wang
# 21785     Sold for:$833,000      Jordan Selwyn , Mark Robinson
# 21786     Sold for:$710,000      Terry Connell , Carmen Holder
# 21787     Sold for:$855,000                     Kelly Sinclair
# 21788   Sold for:$1,112,000                   Safroon Mohammed
# 21789             Passed in                      Bijay Prakash
# 21790     Sold for:$598,500  Ann Lereculey , Katelyn Lereculey
# 21791     Sold for:$925,000                      Lily McDonald
# 21792             Passed In                     Jason Yianakis
# 21793                                   Pip White , Tony White
# 21794             Passed In                         Tony White
# 21795             Passed In                         Jasper Foo
# 21796   Sold for:$1,056,000       Julie Davies , Richard White
# 21797             Passed in            Robin Liu, Stephen Smith
# 21798    Sold for:$675,500,    Mike Robson , Lorraine Marshall
# 21799   Sold for:$1,225,000       Karin McIver , Richard White
#
#       property_id_cleaned      auction_date sold_or_not actiondate0  \
# 21700              585961   31 January 2017    Not_Sold          31
# 21701              587189   31 January 2017        Sold          31
# 21702              586510   31 January 2017        Sold          31
# 21703              587350   31 January 2017        Sold          31
# 21704              587339   31 January 2017    Not_Sold          31
# 21705              585663   4 February 2017    Not_Sold           4
# 21706              587067   4 February 2017        Sold           4
# 21707              586480  February 20 None    Not_Sold    February
# 21708              587069  February 20 None        Sold    February
# 21709              587333  February 20 None        Sold    February
# 21710              HR4399        9 Feb 2017        Sold           9
# 21711            BE192760        9 Feb 2017        Sold           9
# 21712              FM5056        9 Feb 2017        Sold           9
# 21713             CR33524        9 Feb 2017        Sold           9
# 21714            BE192773        9 Feb 2017        Sold           9
# 21715              AH4281        9 Feb 2017        Sold           9
# 21716              AH4294        9 Feb 2017        Sold           9
# 21717              AH4306        9 Feb 2017        Sold           9
# 21718              AH4303        9 Feb 2017        Sold           9
# 21719             CR33466        9 Feb 2017        Sold           9
# 21720              FH4308        9 Feb 2017    Not_Sold           9
# 21721              RL1592        9 Feb 2017        Sold           9
# 21722              FH4310        9 Feb 2017        Sold           9
# 21723             PI45742        9 Feb 2017        Sold           9
# 21724              PD4433        9 Feb 2017        Sold           9
# 21725             PI45774        9 Feb 2017        Sold           9
# 21726             PI45685        9 Feb 2017        Sold           9
# 21727              PD4432        9 Feb 2017        Sold           9
# 21728             PI45362        9 Feb 2017        Sold           9
# 21729              PD4439        8 Feb 2017        Sold           8
# ...                   ...               ...         ...         ...
# 21770              BN3345       12 Feb 2017        Sold          12
# 21771              GH4242       12 Feb 2017        Sold          12
# 21772              FB5487       12 Feb 2017        Sold          12
# 21773             BI35239       12 Feb 2017        Sold          12
# 21774             BI35472       12 Feb 2017        Sold          12
# 21775            MKU22462       11 Feb 2017        Sold          11
# 21776            BS161201       11 Feb 2017    Not_Sold          11
# 21777            MKU22434       11 Feb 2017        Sold          11
# 21778           HOB170110       11 Feb 2017    Not_Sold          11
# 21779              BH5399       11 Feb 2017        Sold          11
# 21780            VP161207       11 Feb 2017        Sold          11
# 21781            PW170101       11 Feb 2017    Not_Sold          11
# 21782              WW5947       11 Feb 2017    Not_Sold          11
# 21783              SN3226        9 Feb 2017        Sold           9
# 21784              586463   7 February 2017    Not_Sold           7
# 21785             BI35495        9 Feb 2017        Sold           9
# 21786             GL29356        9 Feb 2017        Sold           9
# 21787            MKU22426        9 Feb 2017        Sold           9
# 21788            MKU22396        9 Feb 2017        Sold           9
# 21789            PT170103        9 Feb 2017    Not_Sold           9
# 21790            MKU22456        9 Feb 2017        Sold           9
# 21791             GL29896        8 Feb 2017        Sold           8
# 21792             BI35484        8 Feb 2017        Sold           8
# 21793             MJ34799        8 Feb 2017    Not_Sold           8
# 21794             MJ34774        8 Feb 2017        Sold           8
# 21795              ES9857        8 Feb 2017        Sold           8
# 21796              ES9853        8 Feb 2017        Sold           8
# 21797              587481   7 February 2017    Not_Sold           7
# 21798             MTE3282        8 Feb 2017        Sold           8
# 21799              ES9847        8 Feb 2017        Sold           8
#
#       actiondate1 actiondate2 actiondate3
# 21700     January        2017         NaN
# 21701     January        2017         NaN
# 21702     January        2017         NaN
# 21703     January        2017         NaN
# 21704     January        2017         NaN
# 21705    February        2017         NaN
# 21706    February        2017         NaN
# 21707          20        None         NaN
# 21708          20        None         NaN
# 21709          20        None         NaN
# 21710         Feb        2017         NaN
# 21711         Feb        2017         NaN
# 21712         Feb        2017         NaN
# 21713         Feb        2017         NaN
# 21714         Feb        2017         NaN
# 21715         Feb        2017         NaN
# 21716         Feb        2017         NaN
# 21717         Feb        2017         NaN
# 21718         Feb        2017         NaN
# 21719         Feb        2017         NaN
# 21720         Feb        2017         NaN
# 21721         Feb        2017         NaN
# 21722         Feb        2017         NaN
# 21723         Feb        2017         NaN
# 21724         Feb        2017         NaN
# 21725         Feb        2017         NaN
# 21726         Feb        2017         NaN
# 21727         Feb        2017         NaN
# 21728         Feb        2017         NaN
# 21729         Feb        2017         NaN
# ...           ...         ...         ...
# 21770         Feb        2017         NaN
# 21771         Feb        2017         NaN
# 21772         Feb        2017         NaN
# 21773         Feb        2017         NaN
# 21774         Feb        2017         NaN
# 21775         Feb        2017         NaN
# 21776         Feb        2017         NaN
# 21777         Feb        2017         NaN
# 21778         Feb        2017         NaN
# 21779         Feb        2017         NaN
# 21780         Feb        2017         NaN
# 21781         Feb        2017         NaN
# 21782         Feb        2017         NaN
# 21783         Feb        2017         NaN
# 21784    February        2017         NaN
# 21785         Feb        2017         NaN
# 21786         Feb        2017         NaN
# 21787         Feb        2017         NaN
# 21788         Feb        2017         NaN
# 21789         Feb        2017         NaN
# 21790         Feb        2017         NaN
# 21791         Feb        2017         NaN
# 21792         Feb        2017         NaN
# 21793         Feb        2017         NaN
# 21794         Feb        2017         NaN
# 21795         Feb        2017         NaN
# 21796         Feb        2017         NaN
# 21797    February        2017         NaN
# 21798         Feb        2017         NaN
# 21799         Feb        2017         NaN
#
# [100 rows x 16 columns]

# %%
#Pring top 3 and bottom 3 rows
scrapped_data.iloc[np.r_[0:3, -3:0]]
# Out:
#                                         property_address  \
# 0                                 6C/55-57 High St, CBD.
# 1      617/145 Nelson St, CBD. Sugartree Centro build...
# 2      71/8 Thompson Park Rd, Mt Wellington. Thompson...
# 28315                            Belmont, 17 Creamer Ave
# 28316                 Northcote Point, 3/68 Richmond Ave
# 28317                        Devonport, 24 Niccol Avenue
#
#                  property_agency  \
# 0      Ray White City Apartments
# 1      Ray White City Apartments
# 2      Ray White City Apartments
# 28315                  Harcourts
# 28316                  Harcourts
# 28317                  Harcourts
#
#                                          property_agents  \
# 0      Agent(s): Krister Samuel (contact), Damian Pig...
# 1                         Agent(s): Victor Liu (contact)
# 2                          Agent(s): Lucia Gao (contact)
# 28315  Agent(s): Jemma Glancy (contact), Victoria Mul...
# 28316                  Agent(s): David Hibbins (contact)
# 28317                  Agent(s): Maria Stevens (contact)
#
#                                  property_auctiondetails  \
# 0           Auction details: Thursday, 28th February '19
# 1           Auction details: Thursday, 28th February '19
# 2           Auction details: Thursday, 28th February '19
# 28315  Auction details: Sunday 24 Apr 12:00 p.m. (On ...
# 28316  Auction details: Sunday 24 Apr 12:00 p.m. (On ...
# 28317  Auction details: Sunday 24 Apr 11:00 a.m. (On ...
#
#                                         property_details         property_id  \
# 0                         2 bedrooms, 1 bathroom, 83sqm.  Listing ID:2045071
# 1                          1 bedroom, 1 bathroom, 57sqm.  Listing ID:2045089
# 2             2 bedrooms, 2 bathrooms, 1 carpark, 76sqm.  Listing ID:2041156
# 28315  Off street car spaces: 3, Carport: 1, Garage: ...   Listing ID:DP8575
# 28316  Garage: 1, Study: 1, Lounge: 1, Bathroom: 1, B...  Listing ID:BI34397
# 28317  Dining Room: 1,  Total lounges: 2,  Total toil...   Listing ID:DP8567
#
#                   property_region                property_value  \
# 0         Auckland, Auckland City  Sold for:$Sold post $625,000
# 1         Auckland, Auckland City             Sold for:$480,000
# 2         Auckland, Auckland City                     Passed in
# 28315  Auckland, North Shore City           Sold for:$1,675,000
# 28316  Auckland, North Shore City             Sold for:$940,000
# 28317  Auckland, North Shore City           Sold for:$1,560,000
#
#                property_agents_cleaned property_id_cleaned  \
# 0      Krister Samuel , Damian Piggin              2045071
# 1                          Victor Liu              2045089
# 2                           Lucia Gao              2041156
# 28315   Jemma Glancy , Victoria Mules               DP8575
# 28316                   David Hibbins              BI34397
# 28317                   Maria Stevens               DP8567
#
#                           auction_date auction_location
# 0          Thursday, 28th February '19          Offsite
# 1          Thursday, 28th February '19          Offsite
# 2          Thursday, 28th February '19          Offsite
# 28315  Sunday 24 Apr 12:00 p.m. (2016)           Onsite
# 28316  Sunday 24 Apr 12:00 p.m. (2016)           Onsite
# 28317  Sunday 24 Apr 11:00 a.m. (2016)           Onsite

# %%
#Getting auction location
def get_auction_loc(row):
    s = row['property_auctiondetails']
    if '(On site)' in s:
        return 'Onsite'
    else:
        return 'Offsite'

scrapped_data['auction_location'] = scrapped_data.apply(get_auction_loc, axis=1)

# %%
print(len(scrapped_data))
# Out:
# 28318

# %%
#response = requests.get("https://www.interest.co.nz/property/residential-auction-results?region=Auckland&district=Waitakere%20City&area=Hobsonville&agency=-&status=Sold&page=1")
#soup = BeautifulSoup(response.text, "html.parser")
#soup = BeautifulSoup(response.text, "lxml")
#soup.find_all('div', id="padb-property-card")

# %%
#soup.findAll('a')
#soup.find_all('div', id="padb-property-card")

# %%
<div id='padb-property-region'>Auckland, Auckland City </div>
<div id='padb-property-address'>6C/55-57 High St, CBD.</div>
<div id='padb-property-details'>2 bedrooms, 1 bathroom, 83sqm.</div>
<div id='padb-property-other-info'>
    <div id='padb-property-id'><span>Listing ID:<br></span>2045071</div>
    <div id='padb-property-value'><span>Sold for:<br></span>$Sold post $625,000</div>
    <div id='padb-property-value'><span style='text-transform:capitalize;'>Passed in</span></div>
    <div id='padb-property-value'><span>Sold for:<br></span>$Sold Prior<span class='padb-rv-span'>Rating Valuation:</span><br>(July '18)<br>$760,000</div>
</div>
<div id='padb-property-agency'>Ray White City Apartments</div>
<div id='padb-property-agents'><span>Agent(s): </span><a target='_blank' href='https://rwcityapartments.co.nz/agents/krister-samuel/43638'>Krister Samuel (contact)</a>,&nbsp;<a target='_blank' href='https://rwcityapartments.co.nz/agents/krister-samuel/43638'>Damian Piggin (contact)</a>&nbsp;</div>
<div id='padb-property-auction-details'><span>Auction details: </span>Thursday, 28th February '19</div>
---------------------------------------------------
 <div class='padb-wo-left'>
            <div id='padb-property-region'>Auckland, Auckland City</div>
            <div id='padb-property-address'>6C/55-57 High St, CBD.</div><br><div id='padb-property-details'>2 bedrooms, 1 bathroom, 83sqm.</div><br>
            <div id='padb-property-description'><p>Large, liveable layout (83m2). Two bedrooms. Super high stud height. Beautiful casement windows framing a quintessential Auckland outlook, over Queen Street. Chunky construction ensures structural integrity, privacy and over the top sound insulation. Complete peace of mind on offer here. The residence is a part of a boutique complex of only 27 apartments and occupies the top floor. To say opportunities like this are rare is a total understatement. This versatile property has been in the same family for years and has provided solutions as their requirements have evolved. As a lock n leave city pad for the Parents; as a University flat for the kids and most recently as a low maintenance high yielding investment property: It has been the answer.</p>
</div>
          </div>
            <div class='padb-wo-right'>
              <b>Listing ID</b><br>2045071<br><br><b>Auction details: </b><br>Thursday, 28th February '19<br><br>
              <b>Property value</b><br>$Sold post $625,000 <br><br>
              <b>Agent(s):</b><br><a style='color:#25006D;' target='_blank' href='https://rwcityapartments.co.nz/agents/krister-samuel/43638'>Krister Samuel</a><br><a style='color:#25006D;' target='_blank' href='https://rwcityapartments.co.nz/agents/krister-samuel/43638'>Damian Piggin</a><br><br><br><img style='width:100%;' src='/sites/default/files/property-images/ray-white-logo.jpg'><br>
           </div>
          <div style='clear:both'></div>
        </div>

# %%
#Creating the required dataframe
listings_df = pd.DataFrame()
column_names = ['listing_id','property_address','property_region','num_bedroom',
                'num_bathroom','num_garage','selling_agency','selling_agents',
                'auction_day','auction_date','sold_or_not',
                'sale_price','property_valuation_date','property_value']
listings_df = listings_df.reindex(columns=column_names)

# %%
listings_df.head()
# Out:
# Empty DataFrame
# Columns: [listing_id, property_address, property_region, property_details, selling_agency, selling_agents, auction_day, auction_date, sold_or_not, sale_price, property_valuation_date, property_value]
# Index: []

# %%
#Getting listing id
x = "Listing ID:etl1388"
print re.match(r'Listing ID:(.*)', x).group(1)
# Out:
# etl1388

# %%
print text2int ('four bedrooms home, double garage')
print text2int ('three double bedrooms home, garage')
# Out:
# 4 bedrooms home, double garage
# 3 double bedrooms home, garage

# %%
strlist = ['4 bedrooms 2 bathrooms 3 carparks','3 bedroom house',
'Bedrooms 2','beds 5','Bedrooms 1', 'Four bedrooms home, double garage',
'Four bedrooms home','Three double bedrooms home, garage','Three bedrooms home',
'Garage car spaces: 2, Bathrooms: 4, Bedrooms: 7']

# %%
from word2number import w2n
print w2n.word_to_num("Four bedrooms home, double garage")
# Out:
# 4

# %%
s = "4 bedroom 2 bathrooms 3 carparks"
s = "Bedrooms 1,"
#print re.match(r'(.*)bedrooms|bedroom', s).group(1)
print re.search(r'(.*)(?:bedrooms|bedroom)', s,re.I).group(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-d49c554ecaea> in <module>()
#       2 s = "Bedrooms 1,"
#       3 #print re.match(r'(.*)bedrooms|bedroom', s).group(1)
# ----> 4 print re.search(r'(.*)(?:bedrooms|bedroom)', s).group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
# Out:
# 4 bedrooms
# 3 bedroom
# bedrooms 2
# beds 5
# bedrooms 1
# four bedrooms
# four bedrooms
# three double bedrooms
# three bedrooms
# bedrooms: 7

# %%
def get_bedroom_num(s):
    if ':' in s:
        out = re.search(r'(?:Bedrooms:|Bedroom:)(.*)', s,re.I).group(1)
    elif ',' in s:
        out = re.search(r'(?:bedrooms|bedroom|beds)(.*)', s,re.I).group(1)
    else:
        out = re.search(r'(.*)(?:bedrooms|bedroom).*', s,re.I).group(1)
    out = filter(lambda x: x.isdigit(), out)
    return out

# %%
s = "Garage car spaces: 2, Bathrooms: 4, Bedrooms: 7,"
#s = "Bedrooms 1,"
s = "4 bedroom 2 bathrooms 3 carparks"
#s = '4 bedrooms home, double garage'
get_bedroom_num(s)
# Out:
# '4'

# %%
x = "28th February 19"
print re.match(r'(.*)?:st|nd|rd|th', x).group(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-ba0129567f85> in <module>()
#       1 x = "28th February 19"
# ----> 2 print re.match(r'(.*)?:st|nd|rd|th', x).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
#Getting agent names
y = "Agent(s): Anna Swift (contact), Mark Robinson (contact)"
print re.match(r'Agent\(s\):\s(.*)', y).group(1)
# Out:
# Anna Swift (contact), Mark Robinson (contact)

# %%
#Getting auction day, date
z = "Auction details: Sunday, 24th February '19"
#z = 'Auction details:'
print re.match(r'Auction details:\s(.*)', z).group(1)
# Out:
# Sunday, 24th February '19

# %%
xy = 'Sunday 24 Apr 12:00 p.m. (On site)(2016)'
if '(On site)' in xy:
    print('yes')
else:
    print('No')
# Out:
# yes

# %%
#Getting all the sales details
s = "Sold for:$980,000Rating Valuation:(July '17)$1,050,000"
print re.search(r'Sold for:(.*)Rating', s).group(1)
print re.search(r'\((.*)\)',s).group(1)
print re.search(r'\)(.*)', s).group(1)
# Out:
# $980,000
# July '17
# $1,050,000

# %%
s = "Thursday, 28th February '19"
s = "Thursday, 9th March '17"
s = "Sunday 24 Apr 12:00 p.m. (2016)"
s = "18 February 2017, On site"
s = "17 February 2017, Shortland Street, Auckland CBD"
s = "16 Feb 2017, 12:30pm at 2 Lorne Street, Auckland"
s = "November 16 Wednesday 2:00pm at 4 Viaduct Harbour Ave, Auckland(2016)"
s = "17 November 2016, Bruce Mason Centre, Takapuna"
s = "Friday 25 Nov 3:00 p.m. (On Site)(2016)"
s = "Auction details: 14 December 2016, Pukekohe Park"
s = "Auction details:  15th February 2017
 12.30pm, 
                    City Sales House,
                    445 Karangahape Road, Newton,
                    Auckland City 1010"
s = "Auction details: Friday 17 Feb 11:00 a.m. (98 Moorhouse Avenue)(2017)"
s = "Auction details: Friday 17 Feb 10:00 a.m. (Gold Auction Rooms, 471 Papanui Rd)(2017)"
s = "Auction details: Wednesday 27 Apr 1:00 p.m. (17/175 Millwater Parkway, Harcourts)(2016)"
s = "Auction details: Wednesday 27 Apr 1:00 p.m. (On site)(2016)"
s = "Auction details: Wednesday 27 Apr 1:00 p.m. (In Rooms - 923 Whangaparaoa Rd, Man)(2016)"
s = "Auction details: Thu 28 Apr 10:00 a.m., 50 Remuera Rd, Remuera, (2016)"
s = "Auction details: Wed 27 Apr 2:00 p.m., 4 Viaduct Harbour Ave, Auckland, (2016)"
s = "Auction details: Wednesday 1 Jun 6:00 p.m. (95 Manukau Rd Epsom (USP))(2016)"

# %%
#Date 'MON DD, YYYY' extraction
mon = ' (?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|(Nov|Dec)(?:ember)?) '
day1 = r'\d{1,2}' 
year1 = r'\d{4}'
year2 = r'\(\d{4}\)'
dummy = r'.*'

# %%
match = re.search(day1 + mon + year1, "17 February 2017, Shortland Street, Auckland CBD")
print match.group()
# Out:
# 17 February 2017

# %%
match = re.search(day1 + mon + year1, "16 Feb 2017, 12:30pm at 2 Lorne Street, Auckland")
print match.group()
# Out:
# 16 Feb 2017

# %%
match = re.search(day1 + mon + dummy + year2, "Friday 25 Nov 3:00 p.m. (On Site)(2016)")
print match.group()
# Out:
# 25 Nov 3:00 p.m. (On Site)(2016)

# %%
match_pattern = r"\d{4}|\(\d{4}\)|\'\d{2}" 
match = re.search(match_pattern, "Nov 4, '219")
print match.group()
# Out:
# '2

# %%
s = "17 Feb"

from dateutil.parser import parse

parse(s, fuzzy=True).year
# Out:
# 2019

# %%
import re
from datetime import datetime

#Date 'DD/M/YY', 'DD/MM/YYYY', 'D/MM/YYYY' extraction
match = re.search(r'\d{1,2}/\d{1,2}/\d{2,4}', "11/8/16")
print match.group()

#Date 'DD/MM' extraction
match = re.search(r'\d{1,2}/\d{1,2}', "11/21")
print match.group()


#Date 'DD MM YYYY' extraction
match = re.search(r'\d{1,2} \d{1,2} \d{2,4}', "1 8 2016")
print match.group()

#Date 'MON DD, YYYY' extraction
mon = '(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|(Nov|Dec)(?:ember)?)'
match_pattern = r' \d{1,2}, \d{2,4}' 
match = re.search(mon + match_pattern, "Nov 4, 2016")
print match.group()

#Date 'MON. DD. YYYY' extraction
match_pattern = r'. \d{1,2}. \d{2,4}' 
match = re.search(mon + match_pattern, "Nov. 18. 2016")
print match.group()

#Date 'MON. DD. YYYY' extraction
match_pattern = r' \d{1,2} \d{2,4}' 
match = re.search(mon + match_pattern, "Nov 18 2016")
print match.group()

# %%
df = pd.DataFrame({'col2': {0: 'a', 1: 2, 2: np.nan}, 'col1': {0: 'w', 1: 'A', 2: 'B'}})

# %%
df.head()
# Out:
#   col1 col2
# 0    w    a
# 1    A    2
# 2    B  NaN

# %%
dit = {"A":1,"B":2}
df['col1'].map(dit).fillna(df['col1'])
# Out:
# 0    w
# 1    1
# 2    2
# Name: col1, dtype: object
